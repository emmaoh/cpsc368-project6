# %% [markdown]
# # Connecting To MongoDB

# %%
import pymongo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.linear_model import LinearRegression

# %%
CWL = 'haydenh7'
SNUM = '55946628'

if CWL.strip() == "" or CWL == 'Put your CWL here' or SNUM.strip() == "" or SNUM == 'Put your snum here':
    print("You need up to update the value of the CWL and/or SNUM variables before proceeding.")
else:
    connection_string = f"mongodb://{CWL}:a{SNUM}@localhost:27017/{CWL}"
    client = pymongo.MongoClient(connection_string)
    db = client[CWL]["songs"]

# %%
import os
import pymongo
import pandas as pd
from datetime import datetime


CWL  = "haydenh7"  # your CWL username
SNUM = "55946628"  # 8-digit student number

DATA_DIR = os.getcwd()

SPOTIFY_SONGS_CSV   = os.path.join(DATA_DIR, "spotify_songs.csv")
CHARTS_CSV          = os.path.join(DATA_DIR, "charts.csv")
BILLBOARD_WEEKS_CSV = os.path.join(DATA_DIR, "billboard_weeks.csv")


def parse_date(date_str: str) -> datetime:
    
    # parse every date string format to datetime object for mongoDB
    
    date_str = str(date_str).strip()
    if len(date_str) == 4:        # e.g. '2013'
        return datetime.strptime(date_str, "%Y")
    elif len(date_str) == 7:      # e.g. '1967-09'
        return datetime.strptime(date_str, "%Y-%m")
    else:                         # e.g. '2019-06-28'
        return datetime.strptime(date_str, "%Y-%m-%d")

def connect(cwl: str, snum: str) -> pymongo.collection.Collection:

    # connect to server through ssh tunnel
    
    connection_string = f"mongodb://{cwl}:a{snum}@localhost:27017/{cwl}"
    client = pymongo.MongoClient(connection_string)
    db = client[cwl]
    collection = db["songs"]
    print(f"[OK] Connected to MongoDB – database: '{cwl}', collection: 'songs'")
    return collection


def load_csvs() -> tuple:

    songs_df     = pd.read_csv(SPOTIFY_SONGS_CSV)
    charts_df    = pd.read_csv(CHARTS_CSV)
    billboard_df = pd.read_csv(BILLBOARD_WEEKS_CSV)

    print(f"[OK] Loaded CSVs:")
    print(f"     spotify_songs   : {len(songs_df)} rows")
    print(f"     charts          : {len(charts_df)} rows")
    print(f"     billboard_weeks : {len(billboard_df)} rows")
    return songs_df, charts_df, billboard_df


def build_documents(songs_df, charts_df, billboard_df) -> list:
    
    # build_documents combines the three dataframes into a list of mongoDB documents
    
    # group chart entries: {track_id: [ {chart_date, rank, streams}, ... ]}
    
    charts_grouped = {}
    for _, row in charts_df.iterrows():
        tid = row["track_id"]
        entry = {
            "chart_date": parse_date(row["date"]),
            "rank":        int(row["rank"]),
            "streams":     int(float(row["streams"]))
        }
        charts_grouped.setdefault(tid, []).append(entry)

    # group billboard runs: {track_id: [ {instance, end_date, ...}, ... ]}
    
    billboard_grouped = {}
    for _, row in billboard_df.iterrows():
        tid = row["track_id"]
        run = {"instance":           int(row["instance"]),
               "end_date":           parse_date(row["end_date"]),
               "best_week_position": int(row["best_week_position"]),
               "weeks_on_chart":     int(row["weeks_on_chart"])}
        billboard_grouped.setdefault(tid, []).append(run)

    # build one document per song
    
    documents = []
    for _, row in songs_df.iterrows():
        tid = row["track_id"]
        doc = {
            "_id": tid,
            "track_name": str(row["track_name"]),
            "track_artist": str(row["track_artist"]),
            "track_popularity": int(row["track_popularity"]),
            "track_album_release_date": parse_date(row["track_album_release_date"]),
            "audio_features": {"danceability": float(row["danceability"]), 
                               "speechiness":  float(row["speechiness"])},
            "spotify_chart_entries": charts_grouped.get(tid, []),
            "billboard_runs": billboard_grouped.get(tid, [])
        }
        documents.append(doc)

    print(f"[OK] Built {len(documents)} documents")
    return documents


def insert_documents(collection: pymongo.collection.Collection,
                     documents: list) -> None:
    collection.drop()
    print("Dropped existing 'songs' collection (if any)")
    result = collection.insert_many(documents)
    print(f"Inserted {len(result.inserted_ids)} documents into 'songs'")


def verify(collection: pymongo.collection.Collection) -> None:
    """Print a quick sanity check after loading."""
    total = collection.count_documents({})
    with_charts    = collection.count_documents(
        {"spotify_chart_entries": {"$not": {"$size": 0}}}
    )
    with_billboard = collection.count_documents(
        {"billboard_runs": {"$not": {"$size": 0}}}
    )
    sample = collection.find_one({"spotify_chart_entries": {"$not": {"$size": 0}}},
                                  {"track_name": 1, "spotify_chart_entries": {"$slice": 1}})

    print()
    print("=== Verification ===")
    print(f"Total documents        : {total}")
    print(f"With chart entries     : {with_charts}")
    print(f"With billboard runs    : {with_billboard}")
    print(f"Sample document (name) : {sample.get('track_name') if sample else 'N/A'}")


if __name__ == "__main__":
    # Validate credentials are set
    if SNUM == "your_student_num":
        print("[ERROR] Please update CWL and SNUM in the configuration section.")
        exit(1)

    collection           = connect(CWL, SNUM)
    songs_df, charts_df, billboard_df = load_csvs()
    documents            = build_documents(songs_df, charts_df, billboard_df)
    insert_documents(collection, documents)
    verify(collection)
# Out:
# [OK] Connected to MongoDB – database: 'haydenh7', collection: 'songs'
# [OK] Loaded CSVs:
#      spotify_songs   : 2000 rows
#      charts          : 1701 rows
#      billboard_weeks : 297 rows
# [OK] Built 2000 documents
# Dropped existing 'songs' collection (if any)
# Inserted 2000 documents into 'songs'
#
# === Verification ===
# Total documents        : 2000
# With chart entries     : 471
# With billboard runs    : 246
# Sample document (name) : Higher Love

# %%
## Test Connection

db.count_documents({})
# Out:
# 2000

# %% [markdown]
# # Retrieve Track popularity and Audio Features through MongoDB

# %%
cursor = db.find({},{
        "track_popularity": 1,
        "audio_features.danceability": 1,
        "audio_features.speechiness": 1,
        "_id" : 0
})

data = list(cursor)
data
# Out:
# [{'track_popularity': 87,
#   'audio_features': {'danceability': 0.693, 'speechiness': 0.0324}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.67, 'speechiness': 0.295}},
#  {'track_popularity': 39,
#   'audio_features': {'danceability': 0.591, 'speechiness': 0.0289}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.59, 'speechiness': 0.122}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.791, 'speechiness': 0.0439}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.669, 'speechiness': 0.136}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.77, 'speechiness': 0.0602}},
#  {'track_popularity': 67,
#   'audio_features': {'danceability': 0.294, 'speechiness': 0.042}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.46, 'speechiness': 0.05}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.665, 'speechiness': 0.0578}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.591, 'speechiness': 0.079}},
#  {'track_popularity': 30,
#   'audio_features': {'danceability': 0.802, 'speechiness': 0.0715}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.753, 'speechiness': 0.0449}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.674, 'speechiness': 0.147}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.44, 'speechiness': 0.0326}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.673, 'speechiness': 0.0354}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.647, 'speechiness': 0.0552}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.842, 'speechiness': 0.228}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.748, 'speechiness': 0.0338}},
#  {'track_popularity': 96,
#   'audio_features': {'danceability': 0.721, 'speechiness': 0.0657}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.781, 'speechiness': 0.0394}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.791, 'speechiness': 0.11}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.598, 'speechiness': 0.0415}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.7, 'speechiness': 0.0666}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.651, 'speechiness': 0.0375}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.733, 'speechiness': 0.033}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.59, 'speechiness': 0.122}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.592, 'speechiness': 0.0275}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.661, 'speechiness': 0.0566}},
#  {'track_popularity': 63,
#   'audio_features': {'danceability': 0.752, 'speechiness': 0.038}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.807, 'speechiness': 0.0361}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.747, 'speechiness': 0.045}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.719, 'speechiness': 0.0476}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.682, 'speechiness': 0.0435}},
#  {'track_popularity': 95,
#   'audio_features': {'danceability': 0.701, 'speechiness': 0.375}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.552, 'speechiness': 0.342}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.645, 'speechiness': 0.0965}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.584, 'speechiness': 0.0356}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.77, 'speechiness': 0.0495}},
#  {'track_popularity': 17,
#   'audio_features': {'danceability': 0.6, 'speechiness': 0.0394}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.509, 'speechiness': 0.102}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.541, 'speechiness': 0.362}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.741, 'speechiness': 0.0656}},
#  {'track_popularity': 23,
#   'audio_features': {'danceability': 0.51, 'speechiness': 0.0447}},
#  {'track_popularity': 94,
#   'audio_features': {'danceability': 0.88, 'speechiness': 0.0874}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.599, 'speechiness': 0.0984}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.659, 'speechiness': 0.0451}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.737, 'speechiness': 0.0896}},
#  {'track_popularity': 98,
#   'audio_features': {'danceability': 0.803, 'speechiness': 0.298}},
#  {'track_popularity': 97,
#   'audio_features': {'danceability': 0.704, 'speechiness': 0.0994}},
#  {'track_popularity': 93,
#   'audio_features': {'danceability': 0.786, 'speechiness': 0.0882}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.734, 'speechiness': 0.0735}},
#  {'track_popularity': 93,
#   'audio_features': {'danceability': 0.759, 'speechiness': 0.0287}},
#  {'track_popularity': 98,
#   'audio_features': {'danceability': 0.764, 'speechiness': 0.0546}},
#  {'track_popularity': 98,
#   'audio_features': {'danceability': 0.513, 'speechiness': 0.0629}},
#  {'track_popularity': 94,
#   'audio_features': {'danceability': 0.501, 'speechiness': 0.0319}},
#  {'track_popularity': 92,
#   'audio_features': {'danceability': 0.474, 'speechiness': 0.343}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.754, 'speechiness': 0.317}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.591, 'speechiness': 0.0304}},
#  {'track_popularity': 93,
#   'audio_features': {'danceability': 0.531, 'speechiness': 0.111}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.737, 'speechiness': 0.0593}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.448, 'speechiness': 0.064}},
#  {'track_popularity': 93,
#   'audio_features': {'danceability': 0.505, 'speechiness': 0.0438}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.795, 'speechiness': 0.0432}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.759, 'speechiness': 0.029}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.676, 'speechiness': 0.0483}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.825, 'speechiness': 0.0802}},
#  {'track_popularity': 89,
#   'audio_features': {'danceability': 0.865, 'speechiness': 0.0719}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.721, 'speechiness': 0.0927}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.74, 'speechiness': 0.0456}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.708, 'speechiness': 0.0449}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.601, 'speechiness': 0.0671}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.52, 'speechiness': 0.0853}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.693, 'speechiness': 0.0378}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.616, 'speechiness': 0.0298}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.825, 'speechiness': 0.0988}},
#  {'track_popularity': 98,
#   'audio_features': {'danceability': 0.695, 'speechiness': 0.0395}},
#  {'track_popularity': 97,
#   'audio_features': {'danceability': 0.794, 'speechiness': 0.0842}},
#  {'track_popularity': 94,
#   'audio_features': {'danceability': 0.598, 'speechiness': 0.0317}},
#  {'track_popularity': 94,
#   'audio_features': {'danceability': 0.778, 'speechiness': 0.0776}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.529, 'speechiness': 0.418}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.654, 'speechiness': 0.0259}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.64, 'speechiness': 0.187}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.621, 'speechiness': 0.148}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.563, 'speechiness': 0.271}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.477, 'speechiness': 0.0925}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.585, 'speechiness': 0.0327}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.619, 'speechiness': 0.0334}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.857, 'speechiness': 0.0824}},
#  {'track_popularity': 51,
#   'audio_features': {'danceability': 0.58, 'speechiness': 0.0745}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.798, 'speechiness': 0.0442}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.843, 'speechiness': 0.0845}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.755, 'speechiness': 0.0575}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.845, 'speechiness': 0.216}},
#  {'track_popularity': 89,
#   'audio_features': {'danceability': 0.668, 'speechiness': 0.0645}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.745, 'speechiness': 0.287}},
#  {'track_popularity': 68,
#   'audio_features': {'danceability': 0.732, 'speechiness': 0.0287}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.667, 'speechiness': 0.0747}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.61, 'speechiness': 0.309}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.703, 'speechiness': 0.0752}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.727, 'speechiness': 0.0718}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.499, 'speechiness': 0.0502}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.694, 'speechiness': 0.218}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.932, 'speechiness': 0.333}},
#  {'track_popularity': 64,
#   'audio_features': {'danceability': 0.753, 'speechiness': 0.0753}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.878, 'speechiness': 0.102}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.57, 'speechiness': 0.251}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.584, 'speechiness': 0.425}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.738, 'speechiness': 0.0573}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.574, 'speechiness': 0.0463}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.722, 'speechiness': 0.132}},
#  {'track_popularity': 89,
#   'audio_features': {'danceability': 0.64, 'speechiness': 0.187}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.694, 'speechiness': 0.0384}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.736, 'speechiness': 0.0677}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.708, 'speechiness': 0.0422}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.764, 'speechiness': 0.0604}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.703, 'speechiness': 0.0752}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.503, 'speechiness': 0.045}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.614, 'speechiness': 0.157}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.726, 'speechiness': 0.0614}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.658, 'speechiness': 0.0377}},
#  {'track_popularity': 89,
#   'audio_features': {'danceability': 0.687, 'speechiness': 0.0452}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.806, 'speechiness': 0.0683}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.842, 'speechiness': 0.0588}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.53, 'speechiness': 0.0335}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.704, 'speechiness': 0.179}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.732, 'speechiness': 0.0929}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.663, 'speechiness': 0.0473}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.492, 'speechiness': 0.0336}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.505, 'speechiness': 0.221}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.518, 'speechiness': 0.0302}},
#  {'track_popularity': 94,
#   'audio_features': {'danceability': 0.724, 'speechiness': 0.0296}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.754, 'speechiness': 0.0611}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.63, 'speechiness': 0.0253}},
#  {'track_popularity': 100,
#   'audio_features': {'danceability': 0.824, 'speechiness': 0.0924}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.464, 'speechiness': 0.129}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.74, 'speechiness': 0.0456}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.665, 'speechiness': 0.0527}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.529, 'speechiness': 0.151}},
#  {'track_popularity': 89,
#   'audio_features': {'danceability': 0.732, 'speechiness': 0.0287}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.767, 'speechiness': 0.0401}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.528, 'speechiness': 0.0324}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.459, 'speechiness': 0.0573}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.548, 'speechiness': 0.0465}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.765, 'speechiness': 0.03}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.717, 'speechiness': 0.0658}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.652, 'speechiness': 0.042}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.699, 'speechiness': 0.0594}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.851, 'speechiness': 0.0505}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.358, 'speechiness': 0.059}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.611, 'speechiness': 0.0346}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.76, 'speechiness': 0.0466}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.676, 'speechiness': 0.0483}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.778, 'speechiness': 0.334}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.749, 'speechiness': 0.0416}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.752, 'speechiness': 0.0705}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.697, 'speechiness': 0.117}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.771, 'speechiness': 0.0553}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.642, 'speechiness': 0.0848}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.657, 'speechiness': 0.0507}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.71, 'speechiness': 0.0722}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.666, 'speechiness': 0.0419}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.897, 'speechiness': 0.292}},
#  {'track_popularity': 31,
#   'audio_features': {'danceability': 0.68, 'speechiness': 0.129}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.861, 'speechiness': 0.176}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.581, 'speechiness': 0.303}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.68, 'speechiness': 0.04}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.906, 'speechiness': 0.269}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.837, 'speechiness': 0.086}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.747, 'speechiness': 0.081}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.791, 'speechiness': 0.0413}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.834, 'speechiness': 0.222}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.889, 'speechiness': 0.0905}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.605, 'speechiness': 0.0438}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.596, 'speechiness': 0.463}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.64, 'speechiness': 0.0374}},
#  {'track_popularity': 68,
#   'audio_features': {'danceability': 0.764, 'speechiness': 0.0738}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.648, 'speechiness': 0.142}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.701, 'speechiness': 0.202}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.731, 'speechiness': 0.271}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.699, 'speechiness': 0.0891}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.746, 'speechiness': 0.0872}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.854, 'speechiness': 0.137}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.836, 'speechiness': 0.0943}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.752, 'speechiness': 0.253}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.579, 'speechiness': 0.0618}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.798, 'speechiness': 0.0421}},
#  {'track_popularity': 30,
#   'audio_features': {'danceability': 0.725, 'speechiness': 0.323}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.287, 'speechiness': 0.0306}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.726, 'speechiness': 0.0917}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.729, 'speechiness': 0.0364}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.658, 'speechiness': 0.0467}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.4, 'speechiness': 0.461}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.602, 'speechiness': 0.0558}},
#  {'track_popularity': 67,
#   'audio_features': {'danceability': 0.781, 'speechiness': 0.0295}},
#  {'track_popularity': 28,
#   'audio_features': {'danceability': 0.724, 'speechiness': 0.0658}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.596, 'speechiness': 0.097}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.568, 'speechiness': 0.0433}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.56, 'speechiness': 0.321}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.574, 'speechiness': 0.0621}},
#  {'track_popularity': 20,
#   'audio_features': {'danceability': 0.663, 'speechiness': 0.0359}},
#  {'track_popularity': 44,
#   'audio_features': {'danceability': 0.833, 'speechiness': 0.178}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.773, 'speechiness': 0.0958}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.588, 'speechiness': 0.216}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.452, 'speechiness': 0.0385}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.695, 'speechiness': 0.153}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.599, 'speechiness': 0.203}},
#  {'track_popularity': 13,
#   'audio_features': {'danceability': 0.61, 'speechiness': 0.15}},
#  {'track_popularity': 11,
#   'audio_features': {'danceability': 0.714, 'speechiness': 0.039}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.638, 'speechiness': 0.0337}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.892, 'speechiness': 0.378}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.754, 'speechiness': 0.039}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.74, 'speechiness': 0.0446}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.835, 'speechiness': 0.125}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.754, 'speechiness': 0.109}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.626, 'speechiness': 0.0504}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.667, 'speechiness': 0.0378}},
#  {'track_popularity': 52,
#   'audio_features': {'danceability': 0.847, 'speechiness': 0.109}},
#  {'track_popularity': 33,
#   'audio_features': {'danceability': 0.908, 'speechiness': 0.129}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.741, 'speechiness': 0.0381}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.498, 'speechiness': 0.188}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.841, 'speechiness': 0.0484}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.689, 'speechiness': 0.0444}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.776, 'speechiness': 0.237}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.732, 'speechiness': 0.231}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.649, 'speechiness': 0.085}},
#  {'track_popularity': 97,
#   'audio_features': {'danceability': 0.784, 'speechiness': 0.0364}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.802, 'speechiness': 0.0715}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.454, 'speechiness': 0.0446}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.726, 'speechiness': 0.123}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.816, 'speechiness': 0.129}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.908, 'speechiness': 0.102}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.696, 'speechiness': 0.332}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.63, 'speechiness': 0.0363}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.488, 'speechiness': 0.297}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.755, 'speechiness': 0.0896}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.613, 'speechiness': 0.0833}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.826, 'speechiness': 0.0921}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.601, 'speechiness': 0.0486}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.713, 'speechiness': 0.374}},
#  {'track_popularity': 36,
#   'audio_features': {'danceability': 0.797, 'speechiness': 0.0439}},
#  {'track_popularity': 40,
#   'audio_features': {'danceability': 0.878, 'speechiness': 0.102}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.798, 'speechiness': 0.0442}},
#  {'track_popularity': 33,
#   'audio_features': {'danceability': 0.844, 'speechiness': 0.0479}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.692, 'speechiness': 0.0602}},
#  {'track_popularity': 29,
#   'audio_features': {'danceability': 0.614, 'speechiness': 0.0702}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.383, 'speechiness': 0.0703}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.456, 'speechiness': 0.077}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.816, 'speechiness': 0.226}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.905, 'speechiness': 0.332}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.678, 'speechiness': 0.186}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.726, 'speechiness': 0.372}},
#  {'track_popularity': 98,
#   'audio_features': {'danceability': 0.896, 'speechiness': 0.0559}},
#  {'track_popularity': 91,
#   'audio_features': {'danceability': 0.881, 'speechiness': 0.156}},
#  {'track_popularity': 93,
#   'audio_features': {'danceability': 0.769, 'speechiness': 0.367}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.736, 'speechiness': 0.0688}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.816, 'speechiness': 0.341}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.882, 'speechiness': 0.245}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.778, 'speechiness': 0.251}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.802, 'speechiness': 0.146}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.768, 'speechiness': 0.307}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.823, 'speechiness': 0.242}},
#  {'track_popularity': 92,
#   'audio_features': {'danceability': 0.656, 'speechiness': 0.102}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.63, 'speechiness': 0.256}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.732, 'speechiness': 0.161}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.876, 'speechiness': 0.333}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.687, 'speechiness': 0.154}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.741, 'speechiness': 0.503}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.512, 'speechiness': 0.0808}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.799, 'speechiness': 0.169}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.568, 'speechiness': 0.255}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.802, 'speechiness': 0.146}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.886, 'speechiness': 0.334}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.809, 'speechiness': 0.0735}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.854, 'speechiness': 0.172}},
#  {'track_popularity': 46,
#   'audio_features': {'danceability': 0.542, 'speechiness': 0.21}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.747, 'speechiness': 0.179}},
#  {'track_popularity': 44,
#   'audio_features': {'danceability': 0.442, 'speechiness': 0.109}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.831, 'speechiness': 0.046}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.876, 'speechiness': 0.426}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.729, 'speechiness': 0.0666}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.706, 'speechiness': 0.0324}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.796, 'speechiness': 0.147}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.554, 'speechiness': 0.0685}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.901, 'speechiness': 0.251}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.581, 'speechiness': 0.407}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.892, 'speechiness': 0.378}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.872, 'speechiness': 0.155}},
#  {'track_popularity': 59,
#   'audio_features': {'danceability': 0.88, 'speechiness': 0.274}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.698, 'speechiness': 0.052}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.784, 'speechiness': 0.209}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.883, 'speechiness': 0.0633}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.661, 'speechiness': 0.0803}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.837, 'speechiness': 0.276}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.772, 'speechiness': 0.467}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.797, 'speechiness': 0.194}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.611, 'speechiness': 0.856}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.855, 'speechiness': 0.235}},
#  {'track_popularity': 62,
#   'audio_features': {'danceability': 0.842, 'speechiness': 0.0491}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.821, 'speechiness': 0.333}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.786, 'speechiness': 0.127}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.395}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.919, 'speechiness': 0.0997}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.974, 'speechiness': 0.184}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.16}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.966, 'speechiness': 0.0618}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.88, 'speechiness': 0.206}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.792, 'speechiness': 0.0851}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.764, 'speechiness': 0.0588}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.754, 'speechiness': 0.0991}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.906, 'speechiness': 0.243}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.74, 'speechiness': 0.27}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.757, 'speechiness': 0.141}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.635, 'speechiness': 0.0832}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.745, 'speechiness': 0.183}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.938, 'speechiness': 0.312}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.897, 'speechiness': 0.222}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.567, 'speechiness': 0.247}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.854, 'speechiness': 0.172}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.765, 'speechiness': 0.127}},
#  {'track_popularity': 48,
#   'audio_features': {'danceability': 0.617, 'speechiness': 0.0439}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.85, 'speechiness': 0.136}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.866, 'speechiness': 0.0495}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.487, 'speechiness': 0.044}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.915, 'speechiness': 0.0677}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.888, 'speechiness': 0.238}},
#  {'track_popularity': 18,
#   'audio_features': {'danceability': 0.745, 'speechiness': 0.245}},
#  {'track_popularity': 67,
#   'audio_features': {'danceability': 0.946, 'speechiness': 0.114}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.918, 'speechiness': 0.255}},
#  {'track_popularity': 19,
#   'audio_features': {'danceability': 0.694, 'speechiness': 0.398}},
#  {'track_popularity': 16,
#   'audio_features': {'danceability': 0.712, 'speechiness': 0.24}},
#  {'track_popularity': 18,
#   'audio_features': {'danceability': 0.929, 'speechiness': 0.242}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.684, 'speechiness': 0.2}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.805, 'speechiness': 0.139}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.953, 'speechiness': 0.214}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.645, 'speechiness': 0.202}},
#  {'track_popularity': 35,
#   'audio_features': {'danceability': 0.864, 'speechiness': 0.238}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.804, 'speechiness': 0.132}},
#  {'track_popularity': 67,
#   'audio_features': {'danceability': 0.512, 'speechiness': 0.438}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.604, 'speechiness': 0.188}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.885, 'speechiness': 0.367}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.883, 'speechiness': 0.299}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.596, 'speechiness': 0.0255}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.491, 'speechiness': 0.0376}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.585, 'speechiness': 0.0712}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.922, 'speechiness': 0.27}},
#  {'track_popularity': 41,
#   'audio_features': {'danceability': 0.829, 'speechiness': 0.208}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.935, 'speechiness': 0.335}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.886, 'speechiness': 0.334}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.876, 'speechiness': 0.306}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.717, 'speechiness': 0.0809}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.888, 'speechiness': 0.588}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.964, 'speechiness': 0.53}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.787, 'speechiness': 0.401}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.759, 'speechiness': 0.0516}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.964, 'speechiness': 0.421}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.97, 'speechiness': 0.366}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.932, 'speechiness': 0.333}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.808, 'speechiness': 0.442}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.894, 'speechiness': 0.42}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.852, 'speechiness': 0.0579}},
#  {'track_popularity': 87,
#   'audio_features': {'danceability': 0.74, 'speechiness': 0.145}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.85, 'speechiness': 0.0714}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.799, 'speechiness': 0.0717}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.685, 'speechiness': 0.0457}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.797, 'speechiness': 0.0412}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.638, 'speechiness': 0.0504}},
#  {'track_popularity': 47,
#   'audio_features': {'danceability': 0.714, 'speechiness': 0.271}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.677, 'speechiness': 0.0287}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.699, 'speechiness': 0.106}},
#  {'track_popularity': 47,
#   'audio_features': {'danceability': 0.686, 'speechiness': 0.191}},
#  {'track_popularity': 52,
#   'audio_features': {'danceability': 0.745, 'speechiness': 0.287}},
#  {'track_popularity': 41,
#   'audio_features': {'danceability': 0.699, 'speechiness': 0.159}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.872, 'speechiness': 0.242}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.669, 'speechiness': 0.0286}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.745, 'speechiness': 0.0807}},
#  {'track_popularity': 63,
#   'audio_features': {'danceability': 0.922, 'speechiness': 0.309}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.743, 'speechiness': 0.125}},
#  {'track_popularity': 93,
#   'audio_features': {'danceability': 0.886, 'speechiness': 0.188}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.725, 'speechiness': 0.197}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.639, 'speechiness': 0.253}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.794, 'speechiness': 0.0599}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.817, 'speechiness': 0.0621}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.861, 'speechiness': 0.343}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.852, 'speechiness': 0.501}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.734, 'speechiness': 0.0776}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.656, 'speechiness': 0.323}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.89, 'speechiness': 0.124}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.713, 'speechiness': 0.0422}},
#  {'track_popularity': 84,
#   'audio_features': {'danceability': 0.414, 'speechiness': 0.0499}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.559, 'speechiness': 0.17}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.933, 'speechiness': 0.161}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.5, 'speechiness': 0.0363}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.0323}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.579, 'speechiness': 0.027}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.623, 'speechiness': 0.0253}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.392, 'speechiness': 0.0536}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.601, 'speechiness': 0.0286}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.583, 'speechiness': 0.0378}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.378, 'speechiness': 0.0407}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.414, 'speechiness': 0.0278}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.356, 'speechiness': 0.0808}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.8, 'speechiness': 0.0485}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.0476}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.77, 'speechiness': 0.0349}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.826, 'speechiness': 0.0524}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.752, 'speechiness': 0.038}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.703, 'speechiness': 0.0412}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.662, 'speechiness': 0.121}},
#  {'track_popularity': 48,
#   'audio_features': {'danceability': 0.822, 'speechiness': 0.0567}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.773, 'speechiness': 0.153}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.807, 'speechiness': 0.126}},
#  {'track_popularity': 62,
#   'audio_features': {'danceability': 0.591, 'speechiness': 0.0289}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.729, 'speechiness': 0.0316}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.66, 'speechiness': 0.0333}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.901, 'speechiness': 0.126}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.698, 'speechiness': 0.151}},
#  {'track_popularity': 90,
#   'audio_features': {'danceability': 0.548, 'speechiness': 0.081}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.421, 'speechiness': 0.398}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.815, 'speechiness': 0.0897}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.725, 'speechiness': 0.0466}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.795, 'speechiness': 0.0722}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.677, 'speechiness': 0.0295}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.6, 'speechiness': 0.107}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.639, 'speechiness': 0.147}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.95, 'speechiness': 0.29}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.884, 'speechiness': 0.12}},
#  {'track_popularity': 14,
#   'audio_features': {'danceability': 0.792, 'speechiness': 0.094}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.912, 'speechiness': 0.124}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.901, 'speechiness': 0.33}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.75, 'speechiness': 0.124}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.837, 'speechiness': 0.0773}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.653, 'speechiness': 0.167}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.816, 'speechiness': 0.111}},
#  {'track_popularity': 99,
#   'audio_features': {'danceability': 0.621, 'speechiness': 0.148}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.817, 'speechiness': 0.112}},
#  {'track_popularity': 56,
#   'audio_features': {'danceability': 0.745, 'speechiness': 0.287}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.622, 'speechiness': 0.172}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.736, 'speechiness': 0.0454}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.566, 'speechiness': 0.0417}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.776, 'speechiness': 0.128}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.599, 'speechiness': 0.0232}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.602, 'speechiness': 0.129}},
#  {'track_popularity': 64,
#   'audio_features': {'danceability': 0.777, 'speechiness': 0.0844}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.41, 'speechiness': 0.155}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.786, 'speechiness': 0.31}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.757, 'speechiness': 0.114}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.786, 'speechiness': 0.0661}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.553, 'speechiness': 0.0918}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.75, 'speechiness': 0.105}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.652, 'speechiness': 0.0541}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.746, 'speechiness': 0.12}},
#  {'track_popularity': 49,
#   'audio_features': {'danceability': 0.695, 'speechiness': 0.0395}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.643, 'speechiness': 0.0449}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.682, 'speechiness': 0.0875}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.422, 'speechiness': 0.249}},
#  {'track_popularity': 64,
#   'audio_features': {'danceability': 0.608, 'speechiness': 0.374}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.678, 'speechiness': 0.0577}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.589, 'speechiness': 0.373}},
#  {'track_popularity': 68,
#   'audio_features': {'danceability': 0.66, 'speechiness': 0.0333}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.665, 'speechiness': 0.0407}},
#  {'track_popularity': 61,
#   'audio_features': {'danceability': 0.423, 'speechiness': 0.529}},
#  {'track_popularity': 64,
#   'audio_features': {'danceability': 0.912, 'speechiness': 0.0582}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.844, 'speechiness': 0.335}},
#  {'track_popularity': 59,
#   'audio_features': {'danceability': 0.793, 'speechiness': 0.0951}},
#  {'track_popularity': 6,
#   'audio_features': {'danceability': 0.924, 'speechiness': 0.282}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.871, 'speechiness': 0.338}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.88, 'speechiness': 0.0429}},
#  {'track_popularity': 76,
#   'audio_features': {'danceability': 0.943, 'speechiness': 0.106}},
#  {'track_popularity': 88,
#   'audio_features': {'danceability': 0.572, 'speechiness': 0.0308}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.473, 'speechiness': 0.0405}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.735, 'speechiness': 0.315}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.421, 'speechiness': 0.0382}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.521, 'speechiness': 0.239}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.511, 'speechiness': 0.041}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.565, 'speechiness': 0.0318}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.656, 'speechiness': 0.217}},
#  {'track_popularity': 89,
#   'audio_features': {'danceability': 0.351, 'speechiness': 0.0333}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.698, 'speechiness': 0.0597}},
#  {'track_popularity': 85,
#   'audio_features': {'danceability': 0.483, 'speechiness': 0.0402}},
#  {'track_popularity': 26,
#   'audio_features': {'danceability': 0.498, 'speechiness': 0.0621}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.42, 'speechiness': 0.121}},
#  {'track_popularity': 83,
#   'audio_features': {'danceability': 0.553, 'speechiness': 0.0362}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.455, 'speechiness': 0.0563}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.652, 'speechiness': 0.0445}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.614, 'speechiness': 0.157}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.584, 'speechiness': 0.046}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.652, 'speechiness': 0.0318}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.736, 'speechiness': 0.425}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.939, 'speechiness': 0.354}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.855, 'speechiness': 0.0585}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.319, 'speechiness': 0.045}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.645, 'speechiness': 0.0823}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.689, 'speechiness': 0.0301}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.589, 'speechiness': 0.0408}},
#  {'track_popularity': 79,
#   'audio_features': {'danceability': 0.861, 'speechiness': 0.0675}},
#  {'track_popularity': 78,
#   'audio_features': {'danceability': 0.938, 'speechiness': 0.189}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.893, 'speechiness': 0.272}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.888, 'speechiness': 0.305}},
#  {'track_popularity': 82,
#   'audio_features': {'danceability': 0.729, 'speechiness': 0.0315}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.681, 'speechiness': 0.0594}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.548, 'speechiness': 0.0465}},
#  {'track_popularity': 92,
#   'audio_features': {'danceability': 0.511, 'speechiness': 0.2}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.876, 'speechiness': 0.143}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.785, 'speechiness': 0.0409}},
#  {'track_popularity': 15,
#   'audio_features': {'danceability': 0.931, 'speechiness': 0.412}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.307}},
#  {'track_popularity': 86,
#   'audio_features': {'danceability': 0.921, 'speechiness': 0.0804}},
#  {'track_popularity': 18,
# ...
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.69, 'speechiness': 0.174}},
#  {'track_popularity': 68,
#   'audio_features': {'danceability': 0.594, 'speechiness': 0.0398}},
#  {'track_popularity': 50,
#   'audio_features': {'danceability': 0.468, 'speechiness': 0.0478}},
#  {'track_popularity': 42,
#   'audio_features': {'danceability': 0.465, 'speechiness': 0.0648}},
#  {'track_popularity': 50,
#   'audio_features': {'danceability': 0.631, 'speechiness': 0.0398}},
#  {'track_popularity': 21,
#   'audio_features': {'danceability': 0.578, 'speechiness': 0.0409}},
#  {'track_popularity': 63,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.1}},
#  {'track_popularity': 56,
#   'audio_features': {'danceability': 0.715, 'speechiness': 0.0325}},
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.714, 'speechiness': 0.0801}},
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.691, 'speechiness': 0.09}},
#  {'track_popularity': 49,
#   'audio_features': {'danceability': 0.651, 'speechiness': 0.0378}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.59, 'speechiness': 0.0797}},
#  {'track_popularity': 45,
#   'audio_features': {'danceability': 0.438, 'speechiness': 0.0601}},
#  {'track_popularity': 56,
#   'audio_features': {'danceability': 0.59, 'speechiness': 0.0384}},
#  {'track_popularity': 41,
#   'audio_features': {'danceability': 0.461, 'speechiness': 0.0539}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.563, 'speechiness': 0.0283}},
#  {'track_popularity': 57,
#   'audio_features': {'danceability': 0.446, 'speechiness': 0.0279}},
#  {'track_popularity': 16,
#   'audio_features': {'danceability': 0.577, 'speechiness': 0.0501}},
#  {'track_popularity': 48,
#   'audio_features': {'danceability': 0.486, 'speechiness': 0.0497}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.635, 'speechiness': 0.0377}},
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.733, 'speechiness': 0.0403}},
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.627, 'speechiness': 0.0719}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.527, 'speechiness': 0.0323}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.742, 'speechiness': 0.0476}},
#  {'track_popularity': 68,
#   'audio_features': {'danceability': 0.708, 'speechiness': 0.0431}},
#  {'track_popularity': 50,
#   'audio_features': {'danceability': 0.653, 'speechiness': 0.0645}},
#  {'track_popularity': 39,
#   'audio_features': {'danceability': 0.361, 'speechiness': 0.111}},
#  {'track_popularity': 1,
#   'audio_features': {'danceability': 0.732, 'speechiness': 0.0535}},
#  {'track_popularity': 4,
#   'audio_features': {'danceability': 0.673, 'speechiness': 0.0481}},
#  {'track_popularity': 16,
#   'audio_features': {'danceability': 0.628, 'speechiness': 0.0323}},
#  {'track_popularity': 58,
#   'audio_features': {'danceability': 0.555, 'speechiness': 0.033}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.467, 'speechiness': 0.0517}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.722, 'speechiness': 0.0363}},
#  {'track_popularity': 80,
#   'audio_features': {'danceability': 0.501, 'speechiness': 0.0409}},
#  {'track_popularity': 1,
#   'audio_features': {'danceability': 0.64, 'speechiness': 0.266}},
#  {'track_popularity': 67,
#   'audio_features': {'danceability': 0.769, 'speechiness': 0.103}},
#  {'track_popularity': 28,
#   'audio_features': {'danceability': 0.787, 'speechiness': 0.0395}},
#  {'track_popularity': 48,
#   'audio_features': {'danceability': 0.63, 'speechiness': 0.103}},
#  {'track_popularity': 39,
#   'audio_features': {'danceability': 0.617, 'speechiness': 0.0375}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.746, 'speechiness': 0.0683}},
#  {'track_popularity': 29,
#   'audio_features': {'danceability': 0.695, 'speechiness': 0.158}},
#  {'track_popularity': 21,
#   'audio_features': {'danceability': 0.705, 'speechiness': 0.0627}},
#  {'track_popularity': 40,
#   'audio_features': {'danceability': 0.803, 'speechiness': 0.0903}},
#  {'track_popularity': 37,
#   'audio_features': {'danceability': 0.736, 'speechiness': 0.0417}},
#  {'track_popularity': 38,
#   'audio_features': {'danceability': 0.826, 'speechiness': 0.0473}},
#  {'track_popularity': 17,
#   'audio_features': {'danceability': 0.837, 'speechiness': 0.14}},
#  {'track_popularity': 30,
#   'audio_features': {'danceability': 0.636, 'speechiness': 0.0291}},
#  {'track_popularity': 31,
#   'audio_features': {'danceability': 0.486, 'speechiness': 0.115}},
#  {'track_popularity': 37,
#   'audio_features': {'danceability': 0.789, 'speechiness': 0.0553}},
#  {'track_popularity': 35,
#   'audio_features': {'danceability': 0.608, 'speechiness': 0.124}},
#  {'track_popularity': 49,
#   'audio_features': {'danceability': 0.604, 'speechiness': 0.0348}},
#  {'track_popularity': 42,
#   'audio_features': {'danceability': 0.655, 'speechiness': 0.0862}},
#  {'track_popularity': 23,
#   'audio_features': {'danceability': 0.836, 'speechiness': 0.16}},
#  {'track_popularity': 34,
#   'audio_features': {'danceability': 0.705, 'speechiness': 0.0583}},
#  {'track_popularity': 27,
#   'audio_features': {'danceability': 0.567, 'speechiness': 0.139}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.718, 'speechiness': 0.0587}},
#  {'track_popularity': 53,
#   'audio_features': {'danceability': 0.775, 'speechiness': 0.081}},
#  {'track_popularity': 30,
#   'audio_features': {'danceability': 0.847, 'speechiness': 0.053}},
#  {'track_popularity': 41,
#   'audio_features': {'danceability': 0.742, 'speechiness': 0.0387}},
#  {'track_popularity': 29,
#   'audio_features': {'danceability': 0.549, 'speechiness': 0.0483}},
#  {'track_popularity': 54,
#   'audio_features': {'danceability': 0.425, 'speechiness': 0.308}},
#  {'track_popularity': 21,
#   'audio_features': {'danceability': 0.716, 'speechiness': 0.0337}},
#  {'track_popularity': 21,
#   'audio_features': {'danceability': 0.697, 'speechiness': 0.0327}},
#  {'track_popularity': 40,
#   'audio_features': {'danceability': 0.866, 'speechiness': 0.0706}},
#  {'track_popularity': 26,
#   'audio_features': {'danceability': 0.554, 'speechiness': 0.0367}},
#  {'track_popularity': 26,
#   'audio_features': {'danceability': 0.684, 'speechiness': 0.0847}},
#  {'track_popularity': 36,
#   'audio_features': {'danceability': 0.711, 'speechiness': 0.0588}},
#  {'track_popularity': 32,
#   'audio_features': {'danceability': 0.649, 'speechiness': 0.181}},
#  {'track_popularity': 34,
#   'audio_features': {'danceability': 0.392, 'speechiness': 0.059}},
#  {'track_popularity': 21,
#   'audio_features': {'danceability': 0.763, 'speechiness': 0.0626}},
#  {'track_popularity': 36,
#   'audio_features': {'danceability': 0.625, 'speechiness': 0.03}},
#  {'track_popularity': 36,
#   'audio_features': {'danceability': 0.621, 'speechiness': 0.0539}},
#  {'track_popularity': 42,
#   'audio_features': {'danceability': 0.729, 'speechiness': 0.0452}},
#  {'track_popularity': 49,
#   'audio_features': {'danceability': 0.713, 'speechiness': 0.0703}},
#  {'track_popularity': 12,
#   'audio_features': {'danceability': 0.705, 'speechiness': 0.0381}},
#  {'track_popularity': 16,
#   'audio_features': {'danceability': 0.62, 'speechiness': 0.0271}},
#  {'track_popularity': 27,
#   'audio_features': {'danceability': 0.834, 'speechiness': 0.0716}},
#  {'track_popularity': 44,
#   'audio_features': {'danceability': 0.738, 'speechiness': 0.0473}},
#  {'track_popularity': 21,
#   'audio_features': {'danceability': 0.695, 'speechiness': 0.032}},
#  {'track_popularity': 41,
#   'audio_features': {'danceability': 0.74, 'speechiness': 0.0387}},
#  {'track_popularity': 44,
#   'audio_features': {'danceability': 0.638, 'speechiness': 0.0873}},
#  {'track_popularity': 39,
#   'audio_features': {'danceability': 0.704, 'speechiness': 0.026}},
#  {'track_popularity': 21,
#   'audio_features': {'danceability': 0.599, 'speechiness': 0.15}},
#  {'track_popularity': 35,
#   'audio_features': {'danceability': 0.539, 'speechiness': 0.204}},
#  {'track_popularity': 16,
#   'audio_features': {'danceability': 0.738, 'speechiness': 0.0758}},
#  {'track_popularity': 27,
#   'audio_features': {'danceability': 0.802, 'speechiness': 0.112}},
#  {'track_popularity': 37,
#   'audio_features': {'danceability': 0.679, 'speechiness': 0.0427}},
#  {'track_popularity': 30,
#   'audio_features': {'danceability': 0.827, 'speechiness': 0.103}},
#  {'track_popularity': 35,
#   'audio_features': {'danceability': 0.779, 'speechiness': 0.0487}},
#  {'track_popularity': 26,
#   'audio_features': {'danceability': 0.701, 'speechiness': 0.0644}},
#  {'track_popularity': 30,
#   'audio_features': {'danceability': 0.625, 'speechiness': 0.135}},
#  {'track_popularity': 40,
#   'audio_features': {'danceability': 0.677, 'speechiness': 0.033}},
#  {'track_popularity': 31,
#   'audio_features': {'danceability': 0.706, 'speechiness': 0.0324}},
#  {'track_popularity': 27,
#   'audio_features': {'danceability': 0.792, 'speechiness': 0.163}},
#  {'track_popularity': 31,
#   'audio_features': {'danceability': 0.561, 'speechiness': 0.0288}},
#  {'track_popularity': 74,
#   'audio_features': {'danceability': 0.633, 'speechiness': 0.0627}},
#  {'track_popularity': 59,
#   'audio_features': {'danceability': 0.652, 'speechiness': 0.0723}},
#  {'track_popularity': 63,
#   'audio_features': {'danceability': 0.678, 'speechiness': 0.0452}},
#  {'track_popularity': 73,
#   'audio_features': {'danceability': 0.751, 'speechiness': 0.038}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.572, 'speechiness': 0.123}},
#  {'track_popularity': 68,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.0833}},
#  {'track_popularity': 58,
#   'audio_features': {'danceability': 0.781, 'speechiness': 0.0533}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.565, 'speechiness': 0.05}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.839, 'speechiness': 0.0536}},
#  {'track_popularity': 59,
#   'audio_features': {'danceability': 0.658, 'speechiness': 0.0626}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.74, 'speechiness': 0.0839}},
#  {'track_popularity': 81,
#   'audio_features': {'danceability': 0.782, 'speechiness': 0.143}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.785, 'speechiness': 0.0369}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.76, 'speechiness': 0.0409}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.566, 'speechiness': 0.0872}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.737, 'speechiness': 0.0947}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.719, 'speechiness': 0.0613}},
#  {'track_popularity': 72,
#   'audio_features': {'danceability': 0.704, 'speechiness': 0.082}},
#  {'track_popularity': 75,
#   'audio_features': {'danceability': 0.734, 'speechiness': 0.118}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.613, 'speechiness': 0.219}},
#  {'track_popularity': 63,
#   'audio_features': {'danceability': 0.76, 'speechiness': 0.0732}},
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.786, 'speechiness': 0.0816}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.563, 'speechiness': 0.104}},
#  {'track_popularity': 48,
#   'audio_features': {'danceability': 0.652, 'speechiness': 0.0448}},
#  {'track_popularity': 68,
#   'audio_features': {'danceability': 0.787, 'speechiness': 0.037}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.6, 'speechiness': 0.095}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.616, 'speechiness': 0.067}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.76, 'speechiness': 0.131}},
#  {'track_popularity': 71,
#   'audio_features': {'danceability': 0.598, 'speechiness': 0.0545}},
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.632, 'speechiness': 0.0494}},
#  {'track_popularity': 7,
#   'audio_features': {'danceability': 0.702, 'speechiness': 0.0374}},
#  {'track_popularity': 69,
#   'audio_features': {'danceability': 0.674, 'speechiness': 0.0594}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.709, 'speechiness': 0.0312}},
#  {'track_popularity': 1,
#   'audio_features': {'danceability': 0.7, 'speechiness': 0.0869}},
#  {'track_popularity': 64,
#   'audio_features': {'danceability': 0.752, 'speechiness': 0.0656}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.725, 'speechiness': 0.0435}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.718, 'speechiness': 0.0703}},
#  {'track_popularity': 67,
#   'audio_features': {'danceability': 0.58, 'speechiness': 0.05}},
#  {'track_popularity': 0,
#   'audio_features': {'danceability': 0.605, 'speechiness': 0.0385}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.615, 'speechiness': 0.221}},
#  {'track_popularity': 62,
#   'audio_features': {'danceability': 0.673, 'speechiness': 0.0404}},
#  {'track_popularity': 66,
#   'audio_features': {'danceability': 0.745, 'speechiness': 0.0327}},
#  {'track_popularity': 61,
#   'audio_features': {'danceability': 0.75, 'speechiness': 0.0432}},
#  {'track_popularity': 61,
#   'audio_features': {'danceability': 0.709, 'speechiness': 0.0593}},
#  {'track_popularity': 61,
#   'audio_features': {'danceability': 0.76, 'speechiness': 0.0908}},
#  {'track_popularity': 58,
#   'audio_features': {'danceability': 0.649, 'speechiness': 0.0487}},
#  {'track_popularity': 63,
#   'audio_features': {'danceability': 0.64, 'speechiness': 0.0689}},
#  {'track_popularity': 67,
#   'audio_features': {'danceability': 0.764, 'speechiness': 0.0396}},
#  {'track_popularity': 57,
#   'audio_features': {'danceability': 0.697, 'speechiness': 0.136}},
#  {'track_popularity': 65,
#   'audio_features': {'danceability': 0.732, 'speechiness': 0.144}},
#  {'track_popularity': 70,
#   'audio_features': {'danceability': 0.7, 'speechiness': 0.0491}},
#  {'track_popularity': 40,
#   'audio_features': {'danceability': 0.832, 'speechiness': 0.0568}},
#  {'track_popularity': 55,
#   'audio_features': {'danceability': 0.695, 'speechiness': 0.0848}},
#  {'track_popularity': 54,
#   'audio_features': {'danceability': 0.729, 'speechiness': 0.108}},
#  {'track_popularity': 63,
#   'audio_features': {'danceability': 0.791, 'speechiness': 0.0516}},
#  {'track_popularity': 56,
#   'audio_features': {'danceability': 0.817, 'speechiness': 0.194}},
#  {'track_popularity': 60,
#   'audio_features': {'danceability': 0.797, 'speechiness': 0.0388}},
#  {'track_popularity': 56,
#   'audio_features': {'danceability': 0.675, 'speechiness': 0.0627}},
#  {'track_popularity': 42,
#   'audio_features': {'danceability': 0.737, 'speechiness': 0.0369}},
#  {'track_popularity': 45,
#   'audio_features': {'danceability': 0.671, 'speechiness': 0.0615}},
#  {'track_popularity': 54,
#   'audio_features': {'danceability': 0.672, 'speechiness': 0.0875}},
#  {'track_popularity': 30,
#   'audio_features': {'danceability': 0.602, 'speechiness': 0.0289}},
#  {'track_popularity': 64,
#   'audio_features': {'danceability': 0.621, 'speechiness': 0.0523}},
#  {'track_popularity': 52,
#   'audio_features': {'danceability': 0.659, 'speechiness': 0.0545}},
#  {'track_popularity': 54,
#   'audio_features': {'danceability': 0.59, 'speechiness': 0.0437}},
#  {'track_popularity': 16,
#   'audio_features': {'danceability': 0.544, 'speechiness': 0.245}},
#  {'track_popularity': 13,
#   'audio_features': {'danceability': 0.532, 'speechiness': 0.0328}},
#  {'track_popularity': 58,
#   'audio_features': {'danceability': 0.863, 'speechiness': 0.0847}},
#  {'track_popularity': 61,
#   'audio_features': {'danceability': 0.735, 'speechiness': 0.061}},
#  {'track_popularity': 24,
#   'audio_features': {'danceability': 0.6, 'speechiness': 0.031}},
#  {'track_popularity': 27,
#   'audio_features': {'danceability': 0.652, 'speechiness': 0.0441}},
#  {'track_popularity': 56,
#   'audio_features': {'danceability': 0.672, 'speechiness': 0.0472}},
#  {'track_popularity': 77,
#   'audio_features': {'danceability': 0.612, 'speechiness': 0.0509}},
#  {'track_popularity': 2,
#   'audio_features': {'danceability': 0.739, 'speechiness': 0.046}},
#  ...]

# %% [markdown]
# # Read filtered dataset into Pandas dataframe

# %%
df = pd.DataFrame([{
    "danceability": doc["audio_features"]["danceability"],
    "speechiness": doc["audio_features"]["speechiness"],
    "track_popularity": doc["track_popularity"]
} for doc in data])

df
# Out:
#       danceability  speechiness  track_popularity
# 0            0.693       0.0324                87
# 1            0.670       0.2950                83
# 2            0.591       0.0289                39
# 3            0.590       0.1220                83
# 4            0.791       0.0439                83
# ...            ...          ...               ...
# 1995         0.204       0.0420                43
# 1996         0.432       0.0349                42
# 1997         0.303       0.0335                38
# 1998         0.285       0.0295                59
# 1999         0.512       0.0583                45
#
# [2000 rows x 3 columns]

# %%
X = df[["danceability", "speechiness"]]
y = df["track_popularity"]

model = LinearRegression()
model.fit(X, y)

fitted = model.predict(X)
residuals = y - fitted

# %% [markdown]
# # Create QQNorm Plot and Residual vs Fitted Plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

stats.probplot(residuals, dist="norm", plot=axes[0])
axes[0].set_title("QQ Norm Plot")

axes[1].scatter(fitted, residuals, alpha=0.3)
axes[1].axhline(y=0, color='red', linestyle='-')
axes[1].set_xlabel("Fitted Values")
axes[1].set_ylabel("Residuals")
axes[1].set_title("Residuals vs Fitted")
# Out:
# Text(0.5, 1.0, 'Residuals vs Fitted')
