# %%
try:
    # %pip install --user "oracledb" --no-warn-script-location
except Exception as e:
    print("\x1b[31m\u2717 Unexpected error! Please contact course staff\n" +
         "Please include the entire text above and below in your message.")
    raise
# Out:
# Requirement already satisfied: oracledb in /home/jupyter/.local/lib/python3.13/site-packages (3.4.2)
# Requirement already satisfied: cryptography>=3.2.1 in /opt/conda/lib/python3.13/site-packages (from oracledb) (46.0.2)
# Requirement already satisfied: typing_extensions>=4.14.0 in /opt/conda/lib/python3.13/site-packages (from oracledb) (4.15.0)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/lib/python3.13/site-packages (from cryptography>=3.2.1->oracledb) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=3.2.1->oracledb) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Read SQL File

import oracledb

dsn = oracledb.makedsn("localhost", 1522, service_name="stu")
connection = oracledb.connect(user="ora_haydenh7", password="a55946628", dsn=dsn)

cur = connection.cursor()

# read the SQL file
with open("insert_data_v2.sql", "r") as file:
    sql_script = file.read()

# split SQL statements
statements = sql_script.split(";")

# execute each statement
for i, stmt in enumerate(statements, start=1):
    stmt = stmt.strip()
    if stmt:
        try:
            cur.execute(stmt)
        except Exception as e:
            print(f"Skipping error at statement {i}: {e} at {stmt}")

connection.commit()

# %%
cur.execute("SELECT COUNT(*) FROM CHARTS")
print(cur.fetchone())
# Out:
# (1699,)
